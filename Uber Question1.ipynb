# %% [markdown]
# # Question 1 & 2:
# With the highest fare or passenger_count by date, vendor 2014-06-13 had the most trips, 33977
#
# Passenger_count is 406589.5;  Fare_amount is 16969.5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('/Users/xiaoyan/Documents/oa/uber data analyst/green_tripdata_2014-06.csv')
df.VendorID = pd.to_datetime(df.VendorID)
print(df.shape)
# Out:
# (1337759, 20)

# %%
df = df.loc[~((df['Trip_distance'] == 0))]
print(df.shape)
# Out:
# (747227, 20)

# %%
df["Trip_count"] = 1
df.head(5)
# Out:
#                                  VendorID lpep_pickup_datetime  \
# 2 2014-06-01 00:00:00 2014-06-01 02:06:27                    N
#   2014-06-01 00:00:00 2014-06-01 23:33:03                    N
#   2014-06-01 00:00:00 2014-06-01 23:03:03                    N
#   2014-06-01 00:00:00 2014-06-01 04:55:35                    N
#   2014-06-01 00:00:00 2014-06-01 03:59:23                    N
#
#                        Lpep_dropoff_datetime  Store_and_fwd_flag  RateCodeID  \
# 2 2014-06-01 00:00:00                      1                 0.0         0.0
#   2014-06-01 00:00:00                      1                 0.0         0.0
#   2014-06-01 00:00:00                      1                 0.0         0.0
#   2014-06-01 00:00:00                      1                 0.0         0.0
#   2014-06-01 00:00:00                      1                 0.0         0.0
#
#                        Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# ...

# %%
dgroup1 = df.groupby(pd.Grouper(key='VendorID', freq='1D')).sum().sort_values(by='Passenger_count', ascending=False)
dgroup1.head(5)
# Out:
#             Lpep_dropoff_datetime  Store_and_fwd_flag    RateCodeID  \
# VendorID
# 2014-06-13                  34059       -2.507307e+06  1.381901e+06
# 2014-06-06                  31901       -2.348752e+06  1.294548e+06
# 2014-06-20                  32041       -2.361229e+06  1.301374e+06
# 2014-06-27                  31161       -2.296130e+06  1.265481e+06
# 2014-06-07                  29337       -2.159365e+06  1.189939e+06
#
#             Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# VendorID
# 2014-06-13     -2.509138e+06     1.382849e+06              49722
# 2014-06-06     -2.351489e+06     1.296090e+06              47537
# 2014-06-20     -2.361636e+06     1.301557e+06              47601
# 2014-06-27     -2.297131e+06     1.266000e+06              45260
# 2014-06-07     -2.159835e+06     1.190136e+06              44441
#
#             Dropoff_latitude  Passenger_count  Trip_distance  Fare_amount  \
# VendorID
# ...

# %%
dgroup2 = df.groupby(pd.Grouper(key='VendorID', freq='1D')).sum().sort_values(by='Fare_amount', ascending=False)
dgroup2.head(5)
# Out:
#             Lpep_dropoff_datetime  Store_and_fwd_flag    RateCodeID  \
# VendorID
# 2014-06-13                  34059       -2.507307e+06  1.381901e+06
# 2014-06-20                  32041       -2.361229e+06  1.301374e+06
# 2014-06-06                  31901       -2.348752e+06  1.294548e+06
# 2014-06-27                  31161       -2.296130e+06  1.265481e+06
# 2014-06-07                  29337       -2.159365e+06  1.189939e+06
#
#             Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# VendorID
# 2014-06-13     -2.509138e+06     1.382849e+06              49722
# 2014-06-20     -2.361636e+06     1.301557e+06              47601
# 2014-06-06     -2.351489e+06     1.296090e+06              47537
# 2014-06-27     -2.297131e+06     1.266000e+06              45260
# 2014-06-07     -2.159835e+06     1.190136e+06              44441
#
#             Dropoff_latitude  Passenger_count  Trip_distance  Fare_amount  \
# VendorID
# ...

# %%
print(dgroup1["Passenger_count"].max())
print(dgroup2["Fare_amount"].max())
# Out:
# 406589.5
# 16969.5
